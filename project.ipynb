# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('dataset.csv')
df.shape
# Out:
# (18434, 141)

# %%
df.head()
# Out:
#        uniqueid          ts        lat        lng  external_bat_voltage  \
# 0  it_220403501  1709340731  19.069340  78.355148                   NaN
# 1  it_220403501  1709340794  19.069347  78.355141                   NaN
# 2  it_220403501  1709340857  19.069414  78.355179                   NaN
# 3  it_220403501  1709340920  19.069258  78.355225                   NaN
# 4  it_220403501  1709340983  19.069094  78.355339                   NaN
#
#    internal_bat_voltage  engineload  tanklevel  throttle  coolant  ...  \
# 0                   NaN          28        NaN       NaN       33  ...
# 1                   NaN          22        NaN       NaN       41  ...
# 2                   NaN          25        NaN       NaN       48  ...
# 3                   NaN          35        NaN       NaN       52  ...
# 4                   NaN           0        NaN       NaN       57  ...
#
#    live_location  to_be_expired_at  status  event_id  \
# 0            NaN               NaN     NaN       NaN
# 1            NaN               NaN     NaN       NaN
# 2            NaN               NaN     NaN       NaN
# 3            NaN               NaN     NaN       NaN
# 4            NaN               NaN     NaN       NaN
#
#    particulated_trap_inlet_pressure  boost_pressure  \
# 0                               NaN             NaN
# 1                               NaN             NaN
# 2                               NaN             NaN
# 3                               NaN             NaN
# 4                               NaN             NaN
#
#    intake_manifold_1_temperature  air_inlet_pressure  exhaust_gas_temperature  \
# 0                            NaN                 NaN                      NaN
# 1                            NaN                 NaN                      NaN
# 2                            NaN                 NaN                      NaN
# 3                            NaN                 NaN                      NaN
# 4                            NaN                 NaN                      NaN
#
#    adblue_level
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 141 columns]

# %%
df.isnull().sum()
# Out:
# uniqueid                             0
# ts                                   0
# lat                                  0
# lng                                  0
# external_bat_voltage             18434
#                                  ...
# boost_pressure                   18434
# intake_manifold_1_temperature    18434
# air_inlet_pressure               18434
# exhaust_gas_temperature          18434
# adblue_level                      3664
# Length: 141, dtype: int64

# %%
df.dropna(how="all")
# Out:
#            uniqueid          ts        lat        lng  external_bat_voltage  \
# 0      it_220403501  1709340731  19.069340  78.355148                   NaN
# 1      it_220403501  1709340794  19.069347  78.355141                   NaN
# 2      it_220403501  1709340857  19.069414  78.355179                   NaN
# 3      it_220403501  1709340920  19.069258  78.355225                   NaN
# 4      it_220403501  1709340983  19.069094  78.355339                   NaN
# ...             ...         ...        ...        ...                   ...
# 18429  it_220403501  1713635865  18.869371  79.020393                   NaN
# 18430  it_220403501  1713635929  18.867130  79.018272                   NaN
# 18431  it_220403501  1713635993  18.862076  79.013924                   NaN
# 18432  it_220403501  1713636056  18.859493  79.011673                   NaN
# 18433  it_220403501  1713636120  18.858324  79.009033                   NaN
#
#        internal_bat_voltage  engineload  tanklevel  throttle  coolant  ...  \
# 0                       NaN          28        NaN       NaN       33  ...
# 1                       NaN          22        NaN       NaN       41  ...
# 2                       NaN          25        NaN       NaN       48  ...
# 3                       NaN          35        NaN       NaN       52  ...
# 4                       NaN           0        NaN       NaN       57  ...
# ...                     ...         ...        ...       ...      ...  ...
# 18429                   NaN          50        NaN       NaN       89  ...
# 18430                   NaN           0        NaN       NaN       92  ...
# 18431                   NaN          10        NaN       NaN       87  ...
# 18432                   NaN          52        NaN       NaN       87  ...
# 18433                   NaN          72        NaN       NaN       90  ...
#
#        live_location  to_be_expired_at  status  event_id  \
# 0                NaN               NaN     NaN       NaN
# 1                NaN               NaN     NaN       NaN
# 2                NaN               NaN     NaN       NaN
# 3                NaN               NaN     NaN       NaN
# 4                NaN               NaN     NaN       NaN
# ...              ...               ...     ...       ...
# 18429            NaN               NaN     NaN       NaN
# 18430            NaN               NaN     NaN       NaN
# 18431            NaN               NaN     NaN       NaN
# 18432            NaN               NaN     NaN       NaN
# 18433            NaN               NaN     NaN       NaN
#
#        particulated_trap_inlet_pressure  boost_pressure  \
# 0                                   NaN             NaN
# 1                                   NaN             NaN
# 2                                   NaN             NaN
# 3                                   NaN             NaN
# 4                                   NaN             NaN
# ...                                 ...             ...
# 18429                               NaN             NaN
# 18430                               NaN             NaN
# 18431                               NaN             NaN
# 18432                               NaN             NaN
# 18433                               NaN             NaN
#
#        intake_manifold_1_temperature  air_inlet_pressure  \
# 0                                NaN                 NaN
# 1                                NaN                 NaN
# 2                                NaN                 NaN
# 3                                NaN                 NaN
# 4                                NaN                 NaN
# ...                              ...                 ...
# 18429                            NaN                 NaN
# 18430                            NaN                 NaN
# 18431                            NaN                 NaN
# 18432                            NaN                 NaN
# 18433                            NaN                 NaN
#
#        exhaust_gas_temperature  adblue_level
# 0                          NaN           NaN
# 1                          NaN           NaN
# 2                          NaN           NaN
# 3                          NaN           NaN
# 4                          NaN           NaN
# ...                        ...           ...
# 18429                      NaN          60.8
# 18430                      NaN          60.8
# 18431                      NaN          60.8
# 18432                      NaN          60.8
# 18433                      NaN          60.8
#
# [18434 rows x 141 columns]

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.head()
# Out:
#        uniqueid          ts        lat        lng  engineload  coolant  \
# 0  it_220403501  1709340731  19.069340  78.355148          28       33
# 1  it_220403501  1709340794  19.069347  78.355141          22       41
# 2  it_220403501  1709340857  19.069414  78.355179          25       48
# 3  it_220403501  1709340920  19.069258  78.355225          35       52
# 4  it_220403501  1709340983  19.069094  78.355339           0       57
#
#    engineoiltemp  vehiclespeed       rpm  obddistance  ...  \
# 0      1774.9688       0.00000   749.000     60780800  ...
# 1      1774.9688       0.00000  1208.375     60780800  ...
# 2      1774.9688       1.40625   752.625     60780800  ...
# 3      1774.9688       2.81250   996.375     60780820  ...
# 4      1774.9688       4.53125  1065.750     60780840  ...
#
#    engine_throttle_valve1_pos  engine_throttle_valve2_pos  enginefueltemp  \
# 0                       100.0                         102             215
# 1                        99.6                         102             215
# 2                        99.6                         102             215
# 3                        99.6                         102             215
# 4                       100.0                         102             215
#
#    drivers_demand_engine_torque_percent  engine_torque_mode  \
# 0                                     0                   1
# 1                                    19                   2
# 2                                     0                   1
# 3                                    28                   2
# 4                                     1                   2
#
#    accelerator_pedal_pos_2  brake_switch_status  clutch_switch_status  \
# 0                      102             Released              Released
# 1                      102             Released               Pressed
# 2                      102              Pressed               Pressed
# 3                      102             Released               Pressed
# 4                      102             Released               Pressed
#
#    parking_switch_status  adblue_level
# 0                Pressed           NaN
# 1                Pressed           NaN
# 2               Released           NaN
# 3               Released           NaN
# 4               Released           NaN
#
# [5 rows x 33 columns]

# %%
df.dropna(axis=1, how='all', inplace=True)

# %%
df.head()
# Out:
#        uniqueid          ts        lat        lng  engineload  coolant  \
# 0  it_220403501  1709340731  19.069340  78.355148          28       33
# 1  it_220403501  1709340794  19.069347  78.355141          22       41
# 2  it_220403501  1709340857  19.069414  78.355179          25       48
# 3  it_220403501  1709340920  19.069258  78.355225          35       52
# 4  it_220403501  1709340983  19.069094  78.355339           0       57
#
#    engineoiltemp  vehiclespeed       rpm  obddistance  ...  \
# 0      1774.9688       0.00000   749.000     60780800  ...
# 1      1774.9688       0.00000  1208.375     60780800  ...
# 2      1774.9688       1.40625   752.625     60780800  ...
# 3      1774.9688       2.81250   996.375     60780820  ...
# 4      1774.9688       4.53125  1065.750     60780840  ...
#
#    engine_throttle_valve1_pos  engine_throttle_valve2_pos  enginefueltemp  \
# 0                       100.0                         102             215
# 1                        99.6                         102             215
# 2                        99.6                         102             215
# 3                        99.6                         102             215
# 4                       100.0                         102             215
#
#    drivers_demand_engine_torque_percent  engine_torque_mode  \
# 0                                     0                   1
# 1                                    19                   2
# 2                                     0                   1
# 3                                    28                   2
# 4                                     1                   2
#
#    accelerator_pedal_pos_2  brake_switch_status  clutch_switch_status  \
# 0                      102             Released              Released
# 1                      102             Released               Pressed
# 2                      102              Pressed               Pressed
# 3                      102             Released               Pressed
# 4                      102             Released               Pressed
#
#    parking_switch_status  adblue_level
# 0                Pressed           NaN
# 1                Pressed           NaN
# 2               Released           NaN
# 3               Released           NaN
# 4               Released           NaN
#
# [5 rows x 33 columns]

# %%
df.drop(columns=['adblue_level'])
# Out:
#            uniqueid          ts        lat        lng  engineload  coolant  \
# 0      it_220403501  1709340731  19.069340  78.355148          28       33
# 1      it_220403501  1709340794  19.069347  78.355141          22       41
# 2      it_220403501  1709340857  19.069414  78.355179          25       48
# 3      it_220403501  1709340920  19.069258  78.355225          35       52
# 4      it_220403501  1709340983  19.069094  78.355339           0       57
# ...             ...         ...        ...        ...         ...      ...
# 18429  it_220403501  1713635865  18.869371  79.020393          50       89
# 18430  it_220403501  1713635929  18.867130  79.018272           0       92
# 18431  it_220403501  1713635993  18.862076  79.013924          10       87
# 18432  it_220403501  1713636056  18.859493  79.011673          52       87
# 18433  it_220403501  1713636120  18.858324  79.009033          72       90
#
#        engineoiltemp  vehiclespeed       rpm  obddistance  ...  \
# 0          1774.9688       0.00000   749.000     60780800  ...
# 1          1774.9688       0.00000  1208.375     60780800  ...
# 2          1774.9688       1.40625   752.625     60780800  ...
# 3          1774.9688       2.81250   996.375     60780820  ...
# 4          1774.9688       4.53125  1065.750     60780840  ...
# ...              ...           ...       ...          ...  ...
# 18429      1774.9688      14.28125   945.125     71872976  ...
# 18430      1774.9688      38.28125  1130.750     71873344  ...
# 18431      1774.9688      32.34375   749.750     71874064  ...
# 18432      1774.9688      17.71875   820.625     71874464  ...
# 18433      1774.9688      16.21875   765.125     71874816  ...
#
#                                             can_raw_data  \
# 0      0CF00300:D1001CFFFF4C4886,0CF00400:407D9268170...
# 1      0CF00300:D03B16FFFF4C4283,0CF00400:41908FC3250...
# 2      0CF00300:D10019FFFF4C4983,0CF00400:307D8F85170...
# 3      0CF00300:D05423FFFF4C4C82,0CF00400:519998231F0...
# 4      0CF00300:D10800FFFF4C3284,0CF00400:017E7E4E210...
# ...                                                  ...
# 18429  0CF00300:D07432FFFF0C847E,0CF00400:719F9E891D0...
# 18430  0CF00300:D10000FFFF0C307E,0CF00400:017D7D56230...
# 18431  0CF00300:D1000AFFFF0C447D,0CF00400:007D846E170...
# 18432  0CF00300:D08D34FFFF0D707E,0CF00400:38ABA4A5190...
# 18433  0CF00300:D08B48FFFF0C897E,0CF00400:50A9AAE9170...
#
#        engine_throttle_valve1_pos  engine_throttle_valve2_pos  enginefueltemp  \
# 0                           100.0                         102             215
# 1                            99.6                         102             215
# 2                            99.6                         102             215
# 3                            99.6                         102             215
# 4                           100.0                         102             215
# ...                           ...                         ...             ...
# 18429                       100.0                         102             215
# 18430                       100.0                         102             215
# 18431                       100.0                         102             215
# 18432                       100.0                         102             215
# 18433                       100.0                         102             215
#
#        drivers_demand_engine_torque_percent  engine_torque_mode  \
# 0                                         0                   1
# 1                                        19                   2
# 2                                         0                   1
# 3                                        28                   2
# 4                                         1                   2
# ...                                     ...                 ...
# 18429                                    34                   2
# 18430                                     0                   2
# 18431                                     0                   1
# 18432                                    46                   9
# 18433                                    44                   1
#
#        accelerator_pedal_pos_2  brake_switch_status  clutch_switch_status  \
# 0                          102             Released              Released
# 1                          102             Released               Pressed
# 2                          102              Pressed               Pressed
# 3                          102             Released               Pressed
# 4                          102             Released               Pressed
# ...                        ...                  ...                   ...
# 18429                      102             Released               Pressed
# 18430                      102             Released               Pressed
# 18431                      102             Released               Pressed
# 18432                      102             Released               Pressed
# 18433                      102             Released               Pressed
#
#        parking_switch_status
# 0                    Pressed
# 1                    Pressed
# 2                   Released
# 3                   Released
# 4                   Released
# ...                      ...
# 18429               Released
# 18430               Released
# 18431               Released
# 18432               Released
# 18433               Released
#
# [18434 rows x 32 columns]

# %%
df.isnull().sum()
# Out:
# uniqueid                                   0
# ts                                         0
# lat                                        0
# lng                                        0
# engineload                                 0
# coolant                                    0
# engineoiltemp                              0
# vehiclespeed                               0
# rpm                                        0
# obddistance                                0
# runtime                                   14
# engine_torque_percent                      0
# selected_gear                              0
# current_gear                               0
# fuel_consumption                           0
# fuel_level                                 2
# fl_level                                   0
# fuel_rate                                  0
# fuel_economy                               0
# accelerator_pedal_pos                      0
# pluscode                                   0
# vibration_status                           0
# can_raw_data                               0
# engine_throttle_valve1_pos                 0
# engine_throttle_valve2_pos                 0
# enginefueltemp                             0
# drivers_demand_engine_torque_percent       0
# engine_torque_mode                         0
# accelerator_pedal_pos_2                    0
# brake_switch_status                        0
# clutch_switch_status                       0
# parking_switch_status                      0
# adblue_level                            3664
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (14759, 33)

# %%
df.isnull().sum()
# Out:
# uniqueid                                0
# ts                                      0
# lat                                     0
# lng                                     0
# engineload                              0
# coolant                                 0
# engineoiltemp                           0
# vehiclespeed                            0
# rpm                                     0
# obddistance                             0
# runtime                                 0
# engine_torque_percent                   0
# selected_gear                           0
# current_gear                            0
# fuel_consumption                        0
# fuel_level                              0
# fl_level                                0
# fuel_rate                               0
# fuel_economy                            0
# accelerator_pedal_pos                   0
# pluscode                                0
# vibration_status                        0
# can_raw_data                            0
# engine_throttle_valve1_pos              0
# engine_throttle_valve2_pos              0
# enginefueltemp                          0
# drivers_demand_engine_torque_percent    0
# engine_torque_mode                      0
# accelerator_pedal_pos_2                 0
# brake_switch_status                     0
# clutch_switch_status                    0
# parking_switch_status                   0
# adblue_level                            0
# dtype: int64

# %%
df.columns
# Out:
# Index(['uniqueid', 'ts', 'lat', 'lng', 'engineload', 'coolant',
#        'engineoiltemp', 'vehiclespeed', 'rpm', 'obddistance', 'runtime',
#        'engine_torque_percent', 'selected_gear', 'current_gear',
#        'fuel_consumption', 'fuel_level', 'fl_level', 'fuel_rate',
#        'fuel_economy', 'accelerator_pedal_pos', 'pluscode', 'vibration_status',
#        'can_raw_data', 'engine_throttle_valve1_pos',
#        'engine_throttle_valve2_pos', 'enginefueltemp',
#        'drivers_demand_engine_torque_percent', 'engine_torque_mode',
#        'accelerator_pedal_pos_2', 'brake_switch_status',
#        'clutch_switch_status', 'parking_switch_status', 'adblue_level'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(10)
# Out:
#           uniqueid          ts        lat        lng  engineload  coolant  \
# 3664  it_220403501  1710147351  18.686798  78.119743          26       72
# 3665  it_220403501  1710157132  18.686811  78.119736          27       55
# 3666  it_220403501  1710157195  18.686808  78.119736          25       60
# 3667  it_220403501  1710157259  18.687035  78.119812          37       64
# 3668  it_220403501  1710157322  18.687256  78.119469          32       67
# 3669  it_220403501  1710157386  18.688023  78.119682          25       70
# 3670  it_220403501  1710157449  18.689260  78.119171          24       74
# 3671  it_220403501  1710157513  18.691153  78.119736          54       78
# 3672  it_220403501  1710157578  18.695702  78.123184          38       82
# 3673  it_220403501  1710157642  18.700594  78.125809          41       85
#
#       engineoiltemp  vehiclespeed       rpm  obddistance  ...  \
# 3664      1774.9688      0.000000   748.500     63130924  ...
# 3665      1774.9688      0.000000   748.000     63130924  ...
# 3666      1774.9688      0.000000   752.000     63130924  ...
# 3667      1774.9688      1.968750   734.750     63130924  ...
# 3668      1774.9688      6.031250   714.250     63130976  ...
# 3669      1774.9688      5.984375   753.125     63131076  ...
# 3670      1774.9688     19.406250  1263.625     63131216  ...
# 3671      1774.9688     30.375000  1050.500     63131504  ...
# 3672      1774.9688     34.031250   866.750     63132100  ...
# 3673      1774.9688     33.343750   838.625     63132700  ...
#
#       engine_throttle_valve1_pos  engine_throttle_valve2_pos  enginefueltemp  \
# 3664                       100.0                         102             215
# 3665                       100.0                         102             215
# 3666                       100.0                         102             215
# 3667                       100.0                         102             215
# 3668                       100.0                         102             215
# 3669                       100.0                         102             215
# 3670                       100.0                         102             215
# 3671                       100.0                         102             215
# 3672                       100.0                         102             215
# 3673                       100.0                         102             215
#
#       drivers_demand_engine_torque_percent  engine_torque_mode  \
# 3664                                     0                   1
# 3665                                     0                   1
# 3666                                     0                   1
# 3667                                     0                   1
# 3668                                     0                   1
# 3669                                     0                   1
# 3670                                    13                   2
# 3671                                    42                   2
# 3672                                    30                   9
# 3673                                    29                   2
#
#       accelerator_pedal_pos_2  brake_switch_status  clutch_switch_status  \
# 3664                      102             Released               Pressed
# 3665                      102             Released              Released
# 3666                      102             Released              Released
# 3667                      102             Released               Pressed
# 3668                      102             Released               Pressed
# 3669                      102             Released               Pressed
# 3670                      102             Released               Pressed
# 3671                      102             Released               Pressed
# 3672                      102             Released               Pressed
# 3673                      102             Released               Pressed
#
#       parking_switch_status  adblue_level
# 3664                Pressed          52.4
# 3665                Pressed          52.4
# 3666                Pressed          52.4
# 3667               Released          52.4
# 3668               Released          52.4
# 3669               Released          52.4
# 3670               Released          52.4
# 3671               Released          52.4
# 3672               Released          52.4
# 3673               Released          52.4
#
# [10 rows x 33 columns]

# %% [markdown]
# #   Exploratory Data Analysis

# %%
df.describe()
# Out:
#                  ts           lat           lng    engineload       coolant  \
# count  1.475900e+04  14759.000000  14759.000000  14759.000000  14759.000000
# mean   1.712123e+09     18.741720     78.822615     37.470831     84.694288
# std    9.262378e+05      0.886903      3.580002     29.910561      7.764257
# min    1.710147e+09      0.000000      0.000000      0.000000     32.000000
# 25%    1.711369e+09     18.746792     78.721558     10.000000     84.000000
# 50%    1.712104e+09     18.853680     79.088333     29.000000     85.000000
# 75%    1.712997e+09     18.921260     79.352711     64.000000     89.000000
# max    1.713636e+09     19.069500     79.481766    100.000000     98.000000
#
#        engineoiltemp  vehiclespeed           rpm   obddistance       runtime  \
# count   1.475900e+04  14759.000000  14759.000000  1.475900e+04  14759.000000
# mean    1.774969e+03     32.865332    936.091783  6.763425e+07   2164.429758
# std     5.518546e-10     18.070697    338.961160  2.581450e+06     73.598774
# min     1.774969e+03      0.000000      0.000000  6.313092e+07   2036.200000
# 25%     1.774969e+03     21.320312    757.625000  6.537449e+07   2099.600000
# 50%     1.774969e+03     37.406250    955.625000  6.769748e+07   2165.800000
# 75%     1.774969e+03     46.937500   1165.375000  6.998379e+07   2230.100000
# max     1.774969e+03     76.968750   2011.250000  7.187482e+07   2287.100000
#
#        ...  fuel_economy  accelerator_pedal_pos  vibration_status  \
# count  ...  14759.000000           14759.000000           14759.0
# mean   ...     26.993514              34.670994               0.0
# std    ...     45.206607              34.882575               0.0
# min    ...      0.000000               0.000000               0.0
# 25%    ...      1.922852               0.000000               0.0
# 50%    ...      3.402344              31.600000               0.0
# 75%    ...     24.057617              68.800000               0.0
# max    ...    125.500000             100.000000               0.0
#
#        engine_throttle_valve1_pos  engine_throttle_valve2_pos  enginefueltemp  \
# count                14759.000000                     14759.0         14759.0
# mean                    99.753208                       102.0           215.0
# std                      3.260786                         0.0             0.0
# min                     26.800000                       102.0           215.0
# 25%                    100.000000                       102.0           215.0
# 50%                    100.000000                       102.0           215.0
# 75%                    100.000000                       102.0           215.0
# max                    100.000000                       102.0           215.0
#
#        drivers_demand_engine_torque_percent  engine_torque_mode  \
# count                          14759.000000        14759.000000
# mean                              27.987465            5.101091
# std                               28.889243            5.287475
# min                                0.000000            1.000000
# 25%                                0.000000            1.000000
# 50%                               22.000000            2.000000
# 75%                               57.000000            9.000000
# max                               83.000000           15.000000
#
#        accelerator_pedal_pos_2  adblue_level
# count                  14759.0  14759.000000
# mean                     102.0     84.792574
# std                        0.0     15.573255
# min                      102.0     44.400000
# 25%                      102.0     68.800000
# 50%                      102.0     88.400000
# 75%                      102.0     99.200000
# max                      102.0    100.000000
#
# [8 rows x 27 columns]

# %%
df.describe()
# Out:
#                  ts           lat           lng    engineload       coolant  \
# count  1.475900e+04  14759.000000  14759.000000  14759.000000  14759.000000
# mean   1.712123e+09     18.741720     78.822615     37.470831     84.694288
# std    9.262378e+05      0.886903      3.580002     29.910561      7.764257
# min    1.710147e+09      0.000000      0.000000      0.000000     32.000000
# 25%    1.711369e+09     18.746792     78.721558     10.000000     84.000000
# 50%    1.712104e+09     18.853680     79.088333     29.000000     85.000000
# 75%    1.712997e+09     18.921260     79.352711     64.000000     89.000000
# max    1.713636e+09     19.069500     79.481766    100.000000     98.000000
#
#        engineoiltemp  vehiclespeed           rpm   obddistance       runtime  \
# count   1.475900e+04  14759.000000  14759.000000  1.475900e+04  14759.000000
# mean    1.774969e+03     32.865332    936.091783  6.763425e+07   2164.429758
# std     5.518546e-10     18.070697    338.961160  2.581450e+06     73.598774
# min     1.774969e+03      0.000000      0.000000  6.313092e+07   2036.200000
# 25%     1.774969e+03     21.320312    757.625000  6.537449e+07   2099.600000
# 50%     1.774969e+03     37.406250    955.625000  6.769748e+07   2165.800000
# 75%     1.774969e+03     46.937500   1165.375000  6.998379e+07   2230.100000
# max     1.774969e+03     76.968750   2011.250000  7.187482e+07   2287.100000
#
#        ...  fuel_economy  accelerator_pedal_pos  vibration_status  \
# count  ...  14759.000000           14759.000000           14759.0
# mean   ...     26.993514              34.670994               0.0
# std    ...     45.206607              34.882575               0.0
# min    ...      0.000000               0.000000               0.0
# 25%    ...      1.922852               0.000000               0.0
# 50%    ...      3.402344              31.600000               0.0
# 75%    ...     24.057617              68.800000               0.0
# max    ...    125.500000             100.000000               0.0
#
#        engine_throttle_valve1_pos  engine_throttle_valve2_pos  enginefueltemp  \
# count                14759.000000                     14759.0         14759.0
# mean                    99.753208                       102.0           215.0
# std                      3.260786                         0.0             0.0
# min                     26.800000                       102.0           215.0
# 25%                    100.000000                       102.0           215.0
# 50%                    100.000000                       102.0           215.0
# 75%                    100.000000                       102.0           215.0
# max                    100.000000                       102.0           215.0
#
#        drivers_demand_engine_torque_percent  engine_torque_mode  \
# count                          14759.000000        14759.000000
# mean                              27.987465            5.101091
# std                               28.889243            5.287475
# min                                0.000000            1.000000
# 25%                                0.000000            1.000000
# 50%                               22.000000            2.000000
# 75%                               57.000000            9.000000
# max                               83.000000           15.000000
#
#        accelerator_pedal_pos_2  adblue_level
# count                  14759.0  14759.000000
# mean                     102.0     84.792574
# std                        0.0     15.573255
# min                      102.0     44.400000
# 25%                      102.0     68.800000
# 50%                      102.0     88.400000
# 75%                      102.0     99.200000
# max                      102.0    100.000000
#
# [8 rows x 27 columns]

# %%
df.describe(include="object")
# Out:
#             uniqueid   pluscode  \
# count          14759      14759
# unique             1       2256
# top     it_220403501  7JFX29M3+
# freq           14759        269
#
#                                              can_raw_data brake_switch_status  \
# count                                               14759               14759
# unique                                              14235                   2
# top     0CF00300:D10000FFFF0C407E,0CF00400:1E7D7E00000...            Released
# freq                                                   21               13462
#
#        clutch_switch_status parking_switch_status
# count                 14759                 14759
# unique                    2                     2
# top                 Pressed              Released
# freq                  12817                 13338

# %%
import sweetviz as sv
import pandas as pd

report = sv.analyze(df)
report.show_html('report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df, x=i)
    plt.show()

# %%
s=df.select_dtypes(include="number").corr()

# %%
sns.heatmap(s)
# Out:
# <AxesSubplot:>

# %%
df['vehiclespeed'].plot(kind='hist', bins=15, title='Histogram of vehiclespeed')
# Out:
# <AxesSubplot:title={'center':'Histogram of vehiclespeed'}, ylabel='Frequency'>

# %%
pip install sweetviz
# Out:
# Requirement already satisfied: sweetviz in c:\users\kiit\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\kiit\anaconda3\lib\site-packages (from sweetviz) (1.9.1)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\kiit\anaconda3\lib\site-packages (from sweetviz) (3.5.2)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\kiit\anaconda3\lib\site-packages (from sweetviz) (1.24.4)
# Requirement already satisfied: importlib-resources>=1.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from sweetviz) (6.4.5)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\kiit\anaconda3\lib\site-packages (from sweetviz) (4.64.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\kiit\anaconda3\lib\site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\kiit\anaconda3\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\kiit\anaconda3\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kiit\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kiit\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (4.25.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kiit\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kiit\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2022.1)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\kiit\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv
import pandas as pd

report = sv.analyze(df)
report.show_html('report.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
